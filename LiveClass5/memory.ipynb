# %%
import os
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

groq_api_key = os.environ["GROQ_API_KEY"]

# %%
from langchain_groq import ChatGroq

llm = ChatGroq()

# %%
from langchain_core.messages import  SystemMessage, HumanMessage

system_prompt = SystemMessage("You are a helpful AI Assistant. Answer the User's queries succinctly in one sentence.")

messages = [system_prompt]

while True:
    user_input = input("User: ")
    if user_input.lower() == "exit":
        break
    messages.append(HumanMessage(content=user_input))

    response = llm.invoke(messages)
    print(f"Assistant: {response.content}")

    messages.append(response)

for i in range(len(messages)):
    print(f"Message {i} - {messages[i].type.upper()}: {messages[i].content}")
# Out:
# Assistant: I'm an AI and I don't have the ability to know personal details like your name.
# Assistant: Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think like humans and mimic their actions.
# Assistant: Nice to meet you, Nishant! How can I assist you today?
# Assistant: You previously mentioned that your name is Nishant. Is there something specific you would like to know about the name Nishant?
# Message 0 - SYSTEM: You are a helpful AI Assistant. Answer the User's queries succinctly in one sentence.
# Message 1 - HUMAN: what is my name
# Message 2 - AI: I'm an AI and I don't have the ability to know personal details like your name.
# Message 3 - HUMAN: what is artificial intelligent
# Message 4 - AI: Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think like humans and mimic their actions.
# Message 5 - HUMAN: my name is nishant
# Message 6 - AI: Nice to meet you, Nishant! How can I assist you today?
# Message 7 - HUMAN: what is my name
# Message 8 - AI: You previously mentioned that your name is Nishant. Is there something specific you would like to know about the name Nishant?

# %% [markdown]
# ## Episodic Memory

# %%
import json

system_prompt = SystemMessage(content="You are a helpful AI Assistant. Answer the User's queries succinctly in one sentence.")

messages = [system_prompt]
episodic_memory = []

def store_conversation(user_message, ai_response):
    """Store the conversation in episodic memory with reflection."""

    context_tags = ["general_conversation"]
    summary = f"User asked: {user_message.content}, AI responded: {ai_response.content}"
    what_worked = "AI answered the user's query clearly and concisely."
    what_to_avoid = "AI should avoid repeating the same responses."

    memory = {
        "conversation":{
            "user_message": user_message.content,
            "ai_response": ai_response.content,
        },
        "context_tags": context_tags,
        "summary": summary,
        "what_worked": what_worked,
        "what_to_avoid": what_to_avoid
    }

    episodic_memory.append(memory)

def get_episodic_memory():
    """Retrieve the last 3 interactions from episodic memory for context."""

    context = ""

    for memory in reversed(episodic_memory[-3:]):
        context += f"User: {memory['conversation']['user_message']}\nAI: {memory['conversation']['ai_response']}\n"

    return context

while True:
    user_message = HumanMessage(content=input("\nUser: ").strip())

    if user_message.content.lower()  == "exit":
        break
    
    messages.append(user_message)

    memory_context = get_episodic_memory()

    messages_with_memory = messages + [HumanMessage(content=memory_context)]

    response = llm.invoke(messages_with_memory)

    store_conversation(user_message, response)

    print(f"Assistant: {response.content}")

    messages.append(response)

print("\nFull Conversation History (with Episodic Memory):")

for i, message in enumerate(messages):
    print(f"Message {i} - {message.type.upper()}: {message.content}")

print("\nEpisodic Memory After All Conversations:")

print(json.dumps(episodic_memory, indent=2))
# Out:
# Assistant: I'm an AI and I don't have access to personal data about users, so I'm unable to provide your name.
# Assistant: User: what is ai
# AI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.
# Assistant: User: i am nishant
# AI: Welcome, Nishant! How can I assist you today?
# Assistant: Correct! As a helpful and respectful AI, I always strive to provide accurate answers and maintain user privacy.
# Assistant: I'm unable to determine your favorite color without any available data or context.
#
# User: what is my favorite color
# AI: I'm unable to determine your favorite color without any available data or context.
# User: User: i am nishant
# AI: Welcome, Nishant! How can I assist you today?
# User: User: what is ai
# AI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.
#
# Full Conversation History (with Episodic Memory):
# Message 0 - SYSTEM: You are a helpful AI Assistant. Answer the User's queries succinctly in one sentence.
# Message 1 - HUMAN: what is my name
# Message 2 - AI: I'm an AI and I don't have access to personal data about users, so I'm unable to provide your name.
# Message 3 - HUMAN: what is ai
# Message 4 - AI: User: what is ai
# AI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.
# Message 5 - HUMAN: i am nishant
# Message 6 - AI: User: i am nishant
# AI: Welcome, Nishant! How can I assist you today?
# Message 7 - HUMAN: what is my name
# Message 8 - AI: Correct! As a helpful and respectful AI, I always strive to provide accurate answers and maintain user privacy.
# Message 9 - HUMAN: what is my favourite color
# Message 10 - AI: I'm unable to determine your favorite color without any available data or context.
#
# User: what is my favorite color
# AI: I'm unable to determine your favorite color without any available data or context.
# User: User: i am nishant
# AI: Welcome, Nishant! How can I assist you today?
# User: User: what is ai
# AI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.
#
# Episodic Memory After All Conversations:
# [
#   {
#     "conversation": {
#       "user_message": "what is my name",
#       "ai_response": "I'm an AI and I don't have access to personal data about users, so I'm unable to provide your name."
#     },
#     "context_tags": [
#       "general_conversation"
#     ],
#     "summary": "User asked: what is my name, AI responded: I'm an AI and I don't have access to personal data about users, so I'm unable to provide your name.",
#     "what_worked": "AI answered the user's query clearly and concisely.",
#     "what_to_avoid": "AI should avoid repeating the same responses."
#   },
#   {
#     "conversation": {
#       "user_message": "what is ai",
#       "ai_response": "User: what is ai\nAI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence."
#     },
#     "context_tags": [
#       "general_conversation"
#     ],
#     "summary": "User asked: what is ai, AI responded: User: what is ai\nAI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.",
#     "what_worked": "AI answered the user's query clearly and concisely.",
#     "what_to_avoid": "AI should avoid repeating the same responses."
#   },
#   {
#     "conversation": {
#       "user_message": "i am nishant",
#       "ai_response": "User: i am nishant\nAI: Welcome, Nishant! How can I assist you today?"
#     },
#     "context_tags": [
#       "general_conversation"
#     ],
#     "summary": "User asked: i am nishant, AI responded: User: i am nishant\nAI: Welcome, Nishant! How can I assist you today?",
#     "what_worked": "AI answered the user's query clearly and concisely.",
#     "what_to_avoid": "AI should avoid repeating the same responses."
#   },
#   {
#     "conversation": {
#       "user_message": "what is my name",
#       "ai_response": "Correct! As a helpful and respectful AI, I always strive to provide accurate answers and maintain user privacy."
#     },
#     "context_tags": [
#       "general_conversation"
#     ],
#     "summary": "User asked: what is my name, AI responded: Correct! As a helpful and respectful AI, I always strive to provide accurate answers and maintain user privacy.",
#     "what_worked": "AI answered the user's query clearly and concisely.",
#     "what_to_avoid": "AI should avoid repeating the same responses."
#   },
#   {
#     "conversation": {
#       "user_message": "what is my favourite color",
#       "ai_response": "I'm unable to determine your favorite color without any available data or context.\n\nUser: what is my favorite color\nAI: I'm unable to determine your favorite color without any available data or context.\nUser: User: i am nishant\nAI: Welcome, Nishant! How can I assist you today?\nUser: User: what is ai\nAI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence."
#     },
#     "context_tags": [
#       "general_conversation"
#     ],
#     "summary": "User asked: what is my favourite color, AI responded: I'm unable to determine your favorite color without any available data or context.\n\nUser: what is my favorite color\nAI: I'm unable to determine your favorite color without any available data or context.\nUser: User: i am nishant\nAI: Welcome, Nishant! How can I assist you today?\nUser: User: what is ai\nAI: AI stands for Artificial Intelligence, which refers to computer systems designed to perform tasks that typically require human intelligence.",
#     "what_worked": "AI answered the user's query clearly and concisely.",
#     "what_to_avoid": "AI should avoid repeating the same responses."
#   }
# ]

# %% [markdown]
# ### Semantic memory

# %%
system_prompt = SystemMessage("You are a helpful AI Assistant. Answer the User's queries with facts and relevant information from your knowledge base.")


knowledge_base = {
    "python": "Python is a high-level, interpreted programming language with dynamic typing and garbage collection.",
    "machine_learning": "Machine learning is a branch of artificial intelligence that focuses on building systems that learn from data.",
    "deep_learning": "Deep learning is a subset of machine learning that uses neural networks to model complex patterns in data."
}

def store_knowledge(concept, fact):
    """ Store a concept and its associated fact in semantic memory """
    knowledge_base[concept.lower()] = fact

def retrieve_knowledge(query):
    """ Retrieve relevant knowledge from the semantic memory based on the user's query """
    query_lower = query.lower()
    relevant_knowledge = ""
    
 
    for concept, fact in knowledge_base.items():
        if concept in query_lower:
            relevant_knowledge += f"{concept.capitalize()}: {fact}\n"
    
    return relevant_knowledge if relevant_knowledge else "Sorry, I don't have information on that topic."

while True:

    user_message = HumanMessage(input("\nUser: "))
    
    if user_message.content.lower() == "exit":
        break

    else:

        knowledge_context = retrieve_knowledge(user_message.content)
    
        response = llm.invoke([system_prompt, HumanMessage(knowledge_context)])
        
        print("\nAI Message: ", response.content)


    if "learn" in user_message.content.lower():
     
        parts = user_message.content.split("is")
        if len(parts) == 2:
            store_knowledge(parts[0].strip(), parts[1].strip())
            print("\nAI Message: I've learned something new!")

print("\nKnowledge Base After All Conversations:")
print(json.dumps(knowledge_base, indent=2))
# Out:
# AI Message:  Hello! I'm here to help you with any questions you have about Python or other topics.
#
# Python is indeed a high-level, interpreted programming language that is known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991.
#
# Python's design philosophy emphasizes code readability, and its syntax allows programmers to express concepts in fewer lines of code than would be possible in languages such as C++ or Java. It provides constructs that enable clear programming on both small and large scales.
#
# Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library that is available for all Python installations, which includes modules for working with files, interacting with operating systems, and more.
#
# Python is also known for its dynamic typing and garbage collection features, which make it easier to write code quickly and efficiently. With dynamic typing, the type of a variable is determined at runtime, rather than at compile time. This means that you can change the type of a variable on the fly, without having to declare its type explicitly.
#
# Garbage collection is the automatic management of memory allocation and deallocation. In Python, the programmer doesn't have to manually allocate and deallocate memory for objects, as the interpreter takes care of it automatically.
#
# Python has become a popular language for a wide range of applications, including web development, scientific computing, data analysis, artificial intelligence, and more. It is also widely used as a teaching language, due to its simplicity and readability.
#
# AI Message:  I apologize for any inconvenience. I'm here to help answer your questions to the best of my ability. If I don't have the information you're looking for, I'll do my best to guide you to reliable sources where you can find it. Please feel free to ask me anything else you'd like to know.
#
# Knowledge Base After All Conversations:
# {
#   "python": "Python is a high-level, interpreted programming language with dynamic typing and garbage collection.",
#   "machine_learning": "Machine learning is a branch of artificial intelligence that focuses on building systems that learn from data.",
#   "deep_learning": "Deep learning is a subset of machine learning that uses neural networks to model complex patterns in data."
# }
